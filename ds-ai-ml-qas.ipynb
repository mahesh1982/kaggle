# %% [markdown]
# <a href="https://www.kaggle.com/code/maheswarareddyp/ds-ai-ml-qas?scriptVersionId=110699387" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ______ is used for the hidden layers , whereas ______ is used for the outer layer. <br>
# 1). Softmax, sigmoid<br>
# 2). Sigmoid, Softmax<br>
# 3). Softmax, Softmax<br>
# 4). Sigmoid, Sigmoid<br>
