# %% [markdown]
# <a href="https://www.kaggle.com/code/maheswarareddyp/ds-ai-ml-qas?scriptVersionId=113738729" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ***These questions are copied from LinkedIn profile Snigdha Kakkar. Whole credited goes to her, I have copied only for my reference and it may be useful for the required people.***

# %% [markdown]
# __ is used for the hidden layers , whereas __ is used for the outer layer. <br>
# 1). Softmax, sigmoid <br>
# 2). Sigmoid, Softmax <br>
# 3). Softmax, Softmax <br>
# 4). Sigmoid, Sigmoid

# %% [markdown]
# Which of the following is an ensemble learning technique? <br>
# 1). XGBoost<br>
# 2). Decision Tree<br>
# 3). K-Means<br>
# **4). All of the above**

# %% [markdown]
# Which of the following is a way to avoid local minima? <br>
# 1). Increase learning rate<br>
# 2). Momentum & adaptive learning<br>
# 3). Add noise when update weights<br>
# **4). All of the above**

# %% [markdown]
# A feature F1 can take certain value: A, B, C, D, E and F. And, represents grade of students from a college. Here, feature type is: <br>
# 1). Nominal <br>
# **2). Ordinal** <br>
# 3). Ratio <br>
# 4). Interval

# %% [markdown]
# Which of the following is not an application of Autoencoders? <br>
# 1). Image coloring <br>
# 2). Image captioning <br>
# 3). Anomalies & outlier detection <br>
# 4). Dimensionality reduction

# %% [markdown]
# Which is FALSE for Kernels in CNN? <br>
# A.Kernels act as pattern detectors <br>
# B.They can be used in colvolutional as well as fully connected layers <br>
# 1). Only A <br>
# 2). Only B <br>
# 3). Both A and B <br>
# 4). None of them

# %% [markdown]
# How many input nodes are required to process a grayscale image of 28X28? <br>
# 1). 28X1 <br>
# **2). 28x28 <br>**
# 3). 56x1 <br>
# 4). 56X56 <br>

# %% [markdown]
# Gradient Descent computes derivate of loss w.r.t. <br>
# 1). Input <br>
# 2). Bias <br>
# **3). Weights** <br>
# 4). Activation value

# %% [markdown]
# A classifier for apples, bananas & oranges shows a training set error of 0.5%, and a dev set error of 7%. What should we try to improve this <br>
# **1). Increase regularization lambda** <br>
# 2). Decrease regularization lambda <br>
# 3). Reduce the training data <br>
# 4). None of the above

# %% [markdown]
# Which statements is/are true? <br>
# A. Nature of problem determines how outliers are used <br>
# B. Outliers should be identified & removed from dataset <br>
# 1) Only A <br>
# 2). Only B <br>
# 3). Both A and B <br>
# 4). None of the above

# %% [markdown]
# The distance of a feature vector [2,3,-2] from separating plane x1 +2x2 +2x3 +5 = 0 is given by: <br>
# 1). 5 <br>
# 2). 3 <br>
# 3). 3/13 <br>
# 4). 13 <br>

# %% [markdown]
# Which of the following is/are hyper parameters in a neural network? <br>
# Coordinate descent  <br>
# Grid search & Random search <br>
# Cross-validation  <br>
# All of the above

# %% [markdown]
# Which of these is a FALSE statement:
# A. AdaDelta & RMSProp are extension of AdaGrad
# B. RMSProp considers both adaptive learning and momentum <br>
# Only A <br>
# Only B <br>
# Both A and B <br>
# None of the above

# %% [markdown]
# Using larger batch sizes while training a network might lead to _______. <br>
# Lesser accuracy  <br>
# Higher resource’s consumption  <br>
# Overfitting  <br>
# All of the above  <br>
