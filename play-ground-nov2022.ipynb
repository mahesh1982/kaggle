# %% [markdown]
# <a href="https://www.kaggle.com/code/maheswarareddyp/play-ground-nov2022?scriptVersionId=109957980" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import pandas as pd
import numpy as np
import glob, os

# %%
train = pd.read_csv('../input/tabular-playground-series-nov-2022/train_labels.csv')
train.head()
# Out:
#    id  label
# 0   0      0
# 1   1      1
# 2   2      1
# 3   3      1
# 4   4      0

# %%
all_df = pd.DataFrame(np.zeros(40000), columns=['id'])
all_df['id'] = all_df.index

file_list = sorted(glob.glob('../input/tabular-playground-series-nov-2022/submission_files/*.csv'))

# %%
from tqdm.notebook import tqdm, trange
for idx, file in enumerate(tqdm(file_list)):
    all_df[f'pred_{idx}'] = pd.read_csv(file)["pred"].to_numpy()
# Out:
#   0%|          | 0/5000 [00:00<?, ?it/s]
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
all_df.head()
# Out:
#    id    pred_0    pred_1    pred_2    pred_3    pred_4    pred_5    pred_6  \
# 0   0  0.709336  0.799007  0.851891  0.537158  0.623930  0.705970  0.503437
# 1   1  0.452988  0.364453  0.567582  0.354468  0.513818  0.584119  0.454809
# 2   2  0.675462  0.842260  0.800013  0.525229  0.692071  0.715418  0.651008
# 3   3  0.481046  0.577118  0.683032  0.541356  0.630088  0.664514  0.413373
# 4   4  0.957339  0.910337  0.917322  0.874487  0.787595  0.854273  0.843846
#
#      pred_7    pred_8  ...  pred_4990  pred_4991  pred_4992  pred_4993  \
# 0  0.633185  0.641550  ...   0.769207   0.750250   0.663370   0.739333
# 1  0.238501  0.472171  ...   0.640052   0.794052   0.721298   0.804369
# 2  0.609124  0.691198  ...   0.812841   0.779859   0.865657   0.828493
# 3  0.508210  0.526140  ...   0.824703   0.799698   0.800130   0.716604
# 4  0.876749  0.821128  ...   0.934803   0.900150   0.960911   0.906037
#
#    pred_4994  pred_4995  pred_4996  pred_4997  pred_4998  pred_4999
# ...

# %%
all_df.shape
# Out:
# (40000, 5001)
