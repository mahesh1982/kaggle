# %% [markdown]
# <a href="https://www.kaggle.com/code/maheswarareddyp/pytorch-1?scriptVersionId=161716959" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import torch
import torch.optim as optim
import matplotlib.pyplot as plt

# %%
# Creating tensors
tensor_1 = torch.tensor([1,1,0,2])
tensor_1
# Out:
# tensor([1, 1, 0, 2])

# %%
tensor_2 = torch.tensor([[0,0,2,1,2], [1,0,2,2,0]])
tensor_2
# Out:
# tensor([[0, 0, 2, 1, 2],
#         [1, 0, 2, 2, 0]])
